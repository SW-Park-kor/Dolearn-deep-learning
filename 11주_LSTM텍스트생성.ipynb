# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('말뭉치 크기:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 1s 2us/step
# 말뭉치 크기: 600893

# %%
# 60개 글자로 된 시퀀스를 추출합니다.
maxlen = 60

# 세 글자씩 건너 뛰면서 새로운 시퀀스를 샘플링합니다.
step = 3

# 추출한 시퀀스를 담을 리스트
sentences = []

# 타깃(시퀀스 다음 글자)을 담을 리스트
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('시퀀스 개수:', len(sentences))

# 말뭉치에서 고유한 글자를 담은 리스트
chars = sorted(list(set(text)))
print('고유한 글자:', len(chars))
# chars 리스트에 있는 글자와 글자의 인덱스를 매핑한 딕셔너리
char_indices = dict((char, chars.index(char)) for char in chars)

# 글자를 원-핫 인코딩하여 0과 1의 이진 배열로 바꿉니다.
print('벡터화...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# 시퀀스 개수: 200278
# 고유한 글자: 58
# 벡터화...

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

import random
import sys

random.seed(42)
start_index = random.randint(0, len(text) - maxlen - 1)

# 60 에포크 동안 모델을 훈련합니다
for epoch in range(1, 10):
    print('에포크', epoch)
    # 데이터에서 한 번만 반복해서 모델을 학습합니다
    model.fit(x, y, batch_size=128, epochs=1)

    # 무작위로 시드 텍스트를 선택합니다
    seed_text = text[start_index: start_index + maxlen]
    print('--- 시드 텍스트: "' + seed_text + '"')

    # 여러가지 샘플링 온도를 시도합니다
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ 온도:', temperature)
        generated_text = seed_text
        sys.stdout.write(generated_text)

        # 시드 텍스트에서 시작해서 400개의 글자를 생성합니다
        for i in range(400):
            # 지금까지 생성된 글자를 원-핫 인코딩으로 바꿉니다
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            # 다음 글자를 샘플링합니다
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# 에포크 1
# 1565/1565 [==============================] - 206s 129ms/step - loss: 2.2440
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through formed and may complession of the self be and something to the some the same of the superful and soul the are all the soul have and self one of the self in the intervated and the who are the self the stall of the same the same of the self any the sense of the spirit of the same the presented to the superficulty and soul the superfical and the something to the same and the sense of the may the self a
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for one of moral of an an
# the precises different and resired of the who superies the presente of the being or the something may it as been them of the in the as the before the superficuently and self and soul. in
# the worther which same and to complession of the had be typen to may not to the presention of can be dangerous and all betion of the some to the self to an as a command of an any not the ar
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forded but not to conectord of the seltibed
# bastions of itsped to know the curtly and agause. the findly
# beowod. preti now and because of even
# for is been--in in the heart and spir-cotsess affhices of its diffelesty which the repricise of in"taks which all teuthirecely complessed plession of t"uts if, ither lading it presould and the beic and soul--and no it
# duoghahal to its aren;
# onedian of its tho
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through form of the eejsiply becumamphiousnel ? swowdd may
# evely plestion hod lo
# okned leass, it
# phllocisined
# hrabt germaniusally haven borts caaking "thim.
#  ay of a tter syinends an ally meraacce of which self cordous, injudmed of litew carre," it dead bood only chpams," foreum belyity whech incownops
# think renication hablly morocly, inly and whole bayist allescate that vilis.. the "srotously nor enservate
# 에포크 2
# 1565/1565 [==============================] - 179s 114ms/step - loss: 1.6020
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the sense of the sense of the sense the sense of the self the for the sense of the sense of the sense of the sense of the self the sense of the sense and the sense of the sense and the sense of the sense of the self the sense of the servation. the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense o
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the fround for the respection. that the secealing the sense of the emotion of the
# beed, in means, and the prose which is the esserfulness of the finers and mankind which the
# fore the else of the seamilate of the self to the sense of the for it is all the self the relly of the sense of the lable to existed and singlegeness to himself--a presences
# and be their the soul of the religious, the me ste
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foreverwee individualation.
# the low fairame, a the searouthes, afour with the understand laster inhen, in
# tur sint,--i forthing,
# norre spirits,
# spasind and the dece sequiliated
# barlies were from hampinist by can it bad distince to u and because to gan nilethtuct: in prees, however
# herring-butting by other should
# corlublate gendfulness
# the compuriom and, the men
# and an every have the
# greate under spo
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for the stioc to
# than
# europen precise; if
# spin one agoel. our sponony or ippectors wnothired wild apprioninanne, itself?
# tilleance and
# mightsifio
# -of
# their crotful or allodevearing," as
# it is
# supsicilonoraes
# there
# mayes,
# eme world: the ccome
# of ratece to the persectional faialry into drveovers--let sighe-s. and embern to innothing basimated in a theluged when of herant,
# elows; when he bosm
# and gos
# 에포크 3
# 1565/1565 [==============================] - 150s 96ms/step - loss: 1.5213
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for a man is a surful to the developed to the string to the sense of the seems to the sense of the seems to the surfact of the seems to the sense of the stringht of the sense of the stringht of the seems to the seems to the surfact to the seems to the sense of the stringht of the means of the stringht to the seetic seet and in the contrary and the seems to the consideration of the seems to the devel
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the father and the sense of the seriousness of the world of the sense of persuation in the strikt it is the made a honour consideration and say and false of the self-derived a possible" to langual has a surful the precisely he as the liver a surdicate experience and self-controlation of the strange
# and so the protection of the lave to string of the man suther and of the reason of the surfact of
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for the peared," because of pain persocal play typaicy had always their effects the place as fell to atar for a conssorvidely, the pares: and
# appeare, he is a senaes to liees as species and acts a
# moral almoralivary wat actions,
# hence warne with are nevertog to the seatoc, thereforeices, it is
# imagain of ence. it we of they, also noce, in a quiased in the sake asksores this out macies pandation, cat
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for
# . the prebarities,, and barefore, a  far asks sevents? begoer and nothisk., menness!'cy of them, that the
# ibolly themed of pleaso of relas! yur ly
# polsic love circliut diveked"ings to,
# or develop, he would nerhtritald.and, fromtail to lmost of havery nation with ralation, sevilazed of their mnamogor, them, the reaposed and unthat leras and will does,s the
# paided of things to their wans
# evil duc
# 에포크 4
# 1565/1565 [==============================] - 163s 104ms/step - loss: 1.4760
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sentical and a present and the spirits of the self-every the from the self-destruction to the self-considered the sentically considered the state of the state of the sentical and the such a person of the sentions of the such a state of the world of the consequently the states the spirits of the world and the spirits of the serrors of the same the soul of the soul and the spirits of the spiri
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the betaris and some become them and discould have a nothing that the desires to its us to be however the last the value, the good implear man was not the considered of which is saint which is always been and considered from his state it is not a much has and science, and with the responsible and same terrification and preservation is not the consequence of the experiences, the profound of the o
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for group all later
# old nares of a such physical resest as we longing and there does keying matter un-we make the wayratively all. the exceptively. regards--because it is no question
# has the s nooned, as metivest of among consequent, merely atterned from cal
# prevert is oight on it were: it is ados better, strove of higher could be a dreamty, the scardary,
# and eithe me youthi, a handrabres its needs
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for plepaus,is sucf,m of
# the question, being torrough of which docmor
# ours abaution upind, divinuss.
#
# 1gh kniew
# the
# entirers; adole the shuter to concernto, one of risomive other him is noble evolunness.
#
#
# ol learns, on operolatos
# as up taking m-cortul about nobla, contimnest thrseless in the vestimulm-hey
# willing instipent manceds, whatever stroog what was knowlejosments to same oves-foobxish,
# but
#
# 에포크 5
# 1565/1565 [==============================] - 142s 91ms/step - loss: 1.4483
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the suppor the sension and the sensition of the soul, and the sensition of the sensition of the the sensition of the soul as the present of the reason of the sensition of the same the man of the world of the one of the more and the soul of the more and the desire that the thing as the contradict and the morality of the sensition of the same the artists that is the sensition of the world that the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the self-conforally an their thing and sensition of the man is his sour end of the precisely to be the sense in the name
# than the something and soul ever are contrary reading as the most doing and which the tragess of conditions of man which has also allow what are some grad to spearly for these honoris has a so that will so see he weaker and consis an the same at the purished to should an expre
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for self-doidress which has not thar 'world bad he court to speaking
# it aspe is the
# least systems of himself things) of a subjective trighten reis extraves in their power of than soot, he weuld
# in supersible, aracy statesing thingsant in the present uncondound on the your consciously that see had fhom morality, and successfrous," one must attain, who would victab, person
# and
# this vetition of ewnous
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for his intellects, to
# terdis, thes
# is alout yet tas omepating"s-ingation. finolity
# mour, whther; for
# deve hadine on event of moralis
# most fail, beside over souble former. age, then thesly
# drances that if hnow.
#
# 1uthy dealt
# errows of matri), throw thougans and nothish favised, whichine,"" my
# ectatiin of at it:
# evatd,
# over
# knowal, on a  me att-man would like truthipratic reisure, is
# acocquent,
# witho
# 에포크 6
# 1565/1565 [==============================] - 144s 92ms/step - loss: 1.4257
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the more and perhaps the self-developed and the same soul, and the stronger and the self-every constraintly and sufferent in the stronger and the stronger and art of the stronger of the self some soul, the schoold and the stronger and the stronger to the compare of the soul and the stronger of the soul and and the self-contention of the come to the superior and souls of the soul and souls and th
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the possible, and in its object and others and souls of the far as in a mode in
# the soul and the essentual interposic in himself and finally to the comes one religion soul, and even of the deart and the life and spiritual to the dangerable of his own consequently as the fore delights to seed to a such as in the sense of the commaning to the relations of the according to the compare and as europe
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for the dove of the trought, free
# qual teems of thing in himuntion; the taliques account finuloked spiritual
# iopere goessable and itself to the  he
# combed tang men, taking, one
# fore dounds as eviniuss his table to seek music for soul.
#
# 1
# e1no=dy, arrsitually namely century. for distance whiching an immoture or true lkness--of the schook of pall. the gregrifification
# of souls, comprocessive taffellin
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fout. in
# act "discovepuring more
# richougra; there poits, tahe enough are revenge. twicvard as in more, coxrken blunble the change corrnessly decefe--this
# euro mo; the fair course and witin into new souls of hypol of
# the brormber,
# the ifferest a poind as
# while therefore to only to the opposincres".s and consolatces of the greglers, have necvejustified and impulse of
# delights, faith. cork and a garb)
# 에포크 7
# 1565/1565 [==============================] - 143s 91ms/step - loss: 1.4082
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for indeed and the man as it is as a present of the sense of the sense of the sense of the sense of the most different fair to the sensually and the sensually men and sensually something of the sensually and with the sense of the english and reason the sensually the sensually and the most consequences of the religion of the sense of the sense of the same the sensually and the same the sensually the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the religions and discerning the greatness of the same reading as the seriousn, for the individual ourselves, one of the sense of the such and lates the holest of a bad the master of the
# same it of the self sense of the sensually to be an expression of the badness and christian that deeper and men, and not the
# expression of the seriously, the all the man is all the great feeling for a higher
# spi
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through founderos for truth assome of it is, that
# which every know whole medictial
# and rendrmatihe lack and what
# done allovoure has
# accorperations. the essentuating and understands
# ; c-moche
# elsed, and by the origin, language: it does being not good le to moult-latericaln aque as such after a suvers e there is and lif it germand
# indeedpfulneds that or pared among th" typearicanish also have
# only deceived (i
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foreych of the maga,a
# envertion.
#
#
#
# 1m everther and perhap phasec what his initualedatious cjoycult and from the place
# is to clumac. but at theight that horeble, andwithogical foreiven mald. "no this mutially. the the reads after well "my
# assuve . chamsel, of exist itpirt (mather aofowed the presenticted cerror". the valution. leed of retiniged itself
# germond: semphasiond) or graduuation -it i these
# 에포크 8
# 1565/1565 [==============================] - 142s 91ms/step - loss: 1.3961
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fortal the sense is the strength and the desire of the strength the strength and most precisely to the present and soul of the strength as a surbeent of the most present and seems to the strength and self-existing to the strength and morality of the strength and the truth of the strength the most present in the strength and conceptions of the world of the strength and all the most present and soul o
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fortality is the self-part of
# the superiority of the state of the most enough to the sense of the desire the desire of him who has a precisely and seeks, the still interest the new are strong and conception of the belief the present and more absolute it is a the conventions the most power, the strength and the hearts of the most belong in all something surfict, as he has a still be the strength as i
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fortaken--outgume
# well acts an aly moral ethers, the vulging morely or
# "contrisestence byourd, or he would seelf-look enbletily very preren flowituder and the sweak."
# the interest soucas leadous" that with
# have one at the states altoge--as a tempterned
# moralities
# hand, ruinfulned law--or cord of invent.--what sympathy because their demin reflection of the curperation, ethingly defuls
# a reolly; one e
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fortatuded--this under come not the preet of oraticy,
# he strpearr--of mankinally--changed on anywhere
# other my hi. unwithed not more surluge,
# suoticar. for now-dotingance? what
# seess ome, orcigatelled to pleasure.
# leods. unjusture hes wichwalld" unvengle resprect as "vinging gets furth human, who least os the old other have
# lifeff fare it
# feeling. we we great
# custome,
# think.
#
#
# 2alv, sulferiarible a
# 에포크 9
# 1565/1565 [==============================] - 136s 87ms/step - loss: 1.3844
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the powerful and instance of the self-conduct, and the self-religion of such a socially and and means of the same the spirit of the same the self-conducting and the self-responsibitions of the conduct the same and and the such a self-religion and all the self-religion of the spirit of the sense of the spirit of the self-religion of the destruction of the most self-conduct and self-every spirit o
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for hard this conduct. but and it is also not one than itself and that with the religion, and fearful itself has a master itself in the self sense of the bad and all some its also the conducting his expression of superance of the understanding the spirit is as a politics which the society of conditions of the can saint must be a maniftes and equally believe the same for a present conduct of the all
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for one is self quiinfathanted been
# sollol obersbavant from he craver. so keol: hol wistorned--by this enlighteness.--all between thith inforative msychope is also laken to happens to its own itely,nce: he achess. bluntely friendlying takens his modigence? eneching belief for bely being conditionm, its only than why dose so we oppers long from is the goingy blatful, and the heart must is already fin
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foons rasuation,
# this is reachive i sevase, ta. but every combotr and delight thoremy
# foridet", heretely! war-house! ienotive mranblated at him
# aspectuiteing, how rith
# o, the
# error a reeks, have jeem his shart
# even inchansed, rare, insungts to midlatings and refalth," threach dangerous say as let keethal veryive relesinly break power,ine of actr, good a lubture as coupt between
# u utuble buived out?
